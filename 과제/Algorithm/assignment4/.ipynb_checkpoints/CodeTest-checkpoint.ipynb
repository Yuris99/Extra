# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import copy

cities = []
sol = []

# %%
def distance(x, y):
    dist = np.linalg.norm(np.array(x)-np.array(y))
    return dist

# %%
with open ('example_solution.csv', mode='r', newline='') as solution:

    reader = csv.reader(solution)
    for row in reader:
        sol.append(int(row[0]))

    idx = sol.index(0)

    front = sol[idx:]
    back = sol[0:idx]

    sol = front + back

    sol.append(int(0))

with open('TSP.csv', mode='r', newline='') as tsp:
    reader = csv.reader(tsp)
    for row in reader:
        cities.append(row)
        #cities.append([float(item) for item in row])

# %%
df = pd.DataFrame(cities)

df.columns = ['X', 'Y']
df['X'] = pd.to_numeric(df['X'])
df['Y'] = pd.to_numeric(df['Y'])

total_cost = 0

for idx in range(len(sol)-1):

    pos_city_1 = [float(cities[sol[idx]][0]), float(cities[sol[idx]][1])]
    pos_city_2 = [float(cities[sol[idx+1]][0]), float(cities[sol[idx+1]][1])]

    dist = distance(pos_city_1, pos_city_2)

    total_cost += dist

print('final cost: '+ str(total_cost))
# Out:
# final cost: 51314.71550400719

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['X'], df['Y'])

for idx in range(len(sol)-1):
    plt.plot([float(cities[sol[idx]][0]), float(cities[sol[idx+1]][0])], \
            [float(cities[sol[idx]][1]), float(cities[sol[idx+1]][1])], color="blue")
    
plt.xlabel('X')
plt.ylabel('Y')
plt.title('TSP cities plot')
plt.show()

# %%
#모든 경로 구함
def getAllDis(path):
    totalcost = 0
    
    for idx in range(len(path)-1):
        pos_city_1 = [float(cities[path[idx]][0]), float(cities[path[idx]][1])]
        pos_city_2 = [float(cities[path[idx+1]][0]), float(cities[path[idx+1]][1])]

        dist = distance(pos_city_1, pos_city_2)

        totalcost += dist
    return totalcost

# %%
ch_num = 100

chrom = []
chrom_dis = []

allPath = list(range(1000))

for i in range(ch_num):
    path = allPath.copy()
    np.random.shuffle(path)
    chrom.append(path)
    chrom_dis.append(getAllDis(path))

# %%
#순위 선택
def ranksel(ch):
    ch = sorted(ch, key=getAllDis)
    return ch

# %%
#룰렛휠 선택
def roulettesel(chdis):
    costsum = sum(chdis)
    selected = []
    
    for i in range(2):
        sel = np.random.uniform(0, costsum)
        adder = 0
        for i in range(len(chdis)):
            adder += chdis[i]
            if(adder >= sel):
                #selected.append(i)
                selected.append(i)
                break
                
    return selected

# %%
def crossover(s1, s2):
    child = s1.copy()
    child1 = []
    child2 = []
    
    startPoint = int(np.random.random() * len(s1))
    endPoint = int(np.random.random() * len(s1))
    
    if(startPoint > endPoint): startPoint, endPoint = endPoint, startPoint
    
    for i in range(startPoint, endPoint):
        child1.append(s2[i])
        
    
    return child

# %%
def mutation(ch, m_rate = 0.05):
    for i in range(len(ch)):
        if np.random.random() < m_rate:
            j = int(np.random.random() * len(ch))
            ch[i], ch[j] = ch[j], ch[i]
    
    
    return ch

# %%
gencnt = 100
m_rate = 0.01

generate = []

def GA(chrom, chrom_dis):
    plt.figure(figsize=(10,10))
    for tri in range(gencnt):
        chrom = ranksel(chrom)
        
        nextg = []
        nextdis = []
        
        for i in range(len(chrom)):
            selected = roulettesel(chrom_dis)
        
            child = crossover(chrom[selected[0]], chrom[selected[1]])
        
            child = mutation(child, m_rate)
            
            nextg.append(child)
            nextdis.append(getAllDis(child))
            
            
        generate.append(getAllDis(chrom[0]))
        plt.plot(generate)
        #plt.show()

        chrom = nextg
        chrom_dis = nextdis
        
        print("Gen" + str(tri) + ": " + str(getAllDis(chrom[0])))
        
    plt.show()

# %%
GA(chrom, chrom_dis)

plt.plot(generate)
plt.show()
# Out:
# Gen0: 51887.85822352582
# Gen1: 53460.10368651819
# Gen2: 50760.02538549394
# Gen3: 53132.75176500379
# Gen4: 53359.08442870326
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21008/514653993.py in <module>
# ----> 1 GA(chrom, chrom_dis)
#       2
#       3 plt.plot(generate)
#       4 plt.show()
#
# ~\AppData\Local\Temp/ipykernel_21008/1767157880.py in GA(chrom, chrom_dis)
#       7     plt.figure(figsize=(10,10))
#       8     for tri in range(gencnt):
# ----> 9         chrom = ranksel(chrom)
#      10
#      11         nextg = []
#
# ~\AppData\Local\Temp/ipykernel_21008/3265569815.py in ranksel(ch)
#       1 #순위 선택
#       2 def ranksel(ch):
# ----> 3     ch = sorted(ch, key=getAllDis)
#       4     return ch
#       5
#
# ~\AppData\Local\Temp/ipykernel_21008/2356037944.py in getAllDis(path)
#       7         pos_city_2 = [float(cities[path[idx+1]][0]), float(cities[path[idx+1]][1])]
#       8
# ----> 9         dist = distance(pos_city_1, pos_city_2)
#      10
#      11         totalcost += dist
#
# ~\AppData\Local\Temp/ipykernel_21008/3529450041.py in distance(x, y)
#       1 def distance(x, y):
# ----> 2     dist = np.linalg.norm(np.array(x)-np.array(y))
#       3     return dist
#
# <__array_function__ internals> in norm(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2527                 sqnorm = dot(x.real, x.real) + dot(x.imag, x.imag)
#    2528             else:
# -> 2529                 sqnorm = dot(x, x)
#    2530             ret = sqrt(sqnorm)
#    2531             if keepdims:
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
